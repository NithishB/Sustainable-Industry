# %%
import pandas as pd
import numpy as np

# %%
tv = pd.read_csv("train_values.csv")

# %%
tv.head()
# Out:
#    row_id  process_id  object_id      phase            timestamp pipeline  \
# 0       0       20001        405  pre_rinse  2018-04-15 04:20:47       L4
# 1       1       20001        405  pre_rinse  2018-04-15 04:20:49       L4
# 2       2       20001        405  pre_rinse  2018-04-15 04:20:51       L4
# 3       3       20001        405  pre_rinse  2018-04-15 04:20:53       L4
# 4       4       20001        405  pre_rinse  2018-04-15 04:20:55       L4
#
#    supply_flow  supply_pressure  return_temperature  return_conductivity  ...  \
# 0     8550.348         0.615451           18.044704             4.990765  ...
# 1    11364.294         0.654297           18.229168             3.749680  ...
# 2    12174.479         0.699870           18.395544             2.783954  ...
# 3    13436.776         0.761502           18.583622             1.769353  ...
# 4    13776.766         0.837240           18.627026             0.904020  ...
#
# ...

# %%
tv.describe()
# Out:
#              row_id    process_id     object_id   supply_flow  \
# count  5.987820e+06  5.987820e+06  5.987820e+06  5.987820e+06
# mean   2.993910e+06  2.402626e+04  5.774687e+02  2.063859e+04
# std    1.728535e+06  2.315437e+03  3.485798e+02  1.726843e+04
# min    0.000000e+00  2.000100e+04  1.020000e+02 -9.481482e+04
# 25%    1.496955e+06  2.203900e+04  2.170000e+02  3.770255e+03
# 50%    2.993910e+06  2.406300e+04  4.260000e+02  2.155671e+04
# 75%    4.490864e+06  2.601600e+04  9.340000e+02  3.140010e+04
# max    5.987819e+06  2.798900e+04  9.770000e+02  1.031612e+05
#
#        supply_pressure  return_temperature  return_conductivity  \
# count     5.987820e+06        5.987820e+06         5.987820e+06
# mean      9.900358e-01        5.573105e+01         2.850323e+01
# std       1.362277e+00        2.470911e+01         2.075043e+01
# min      -1.145833e-01        0.000000e+00         0.000000e+00
# 25%       1.041667e-02        2.916667e+01         1.671371e+00
# ...

# %%
tl = pd.read_csv("train_labels.csv")

# %%
tl.head()
# Out:
#    process_id  final_rinse_total_turbidity_liter
# 0       20001                       4.318275e+06
# 1       20002                       4.375286e+05
# 2       20003                       4.271977e+05
# 3       20004                       7.197830e+05
# 4       20005                       4.133107e+05

# %%
tl.shape
# Out:
# (5021, 2)

# %%
tv.shape
# Out:
# (5987820, 36)

# %%
tv[tv['process_id']==20004]
# Out:
#       row_id  process_id  object_id        phase            timestamp  \
# 4950    4950       20004        921    pre_rinse  2018-03-23 06:42:01
# 4951    4951       20004        921    pre_rinse  2018-03-23 06:42:03
# 4952    4952       20004        921    pre_rinse  2018-03-23 06:42:05
# 4953    4953       20004        921    pre_rinse  2018-03-23 06:42:07
# 4954    4954       20004        921    pre_rinse  2018-03-23 06:42:09
# 4955    4955       20004        921    pre_rinse  2018-03-23 06:42:11
# 4956    4956       20004        921    pre_rinse  2018-03-23 06:42:13
# 4957    4957       20004        921    pre_rinse  2018-03-23 06:42:15
# 4958    4958       20004        921    pre_rinse  2018-03-23 06:42:17
# 4959    4959       20004        921    pre_rinse  2018-03-23 06:42:19
# 4960    4960       20004        921    pre_rinse  2018-03-23 06:42:21
# 4961    4961       20004        921    pre_rinse  2018-03-23 06:42:23
# ...
